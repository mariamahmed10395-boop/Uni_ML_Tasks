# %% [markdown]
# ##Task_1
# ##Lab_2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\zbook g6\Uni_ML_Task\Uni_ML_Tasks\tasks\heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['age', 'trestbps', 'chol', 'thalach']])
plt.title('Outliers Detection for Numerical Features')
plt.show()

# %%
print("\nTarget Distribution:")
print(df['target'].value_counts(normalize=True))
# Out:
# Target Distribution:
# target
# 1    0.513171
# 0    0.486829
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='thalach', hue='target', data=df, palette='RdBu')

plt.title('Heart Disease: Age vs Max Heart Rate')
plt.xlabel('Age')
plt.ylabel('Max Heart Rate (thalach)')
plt.legend(["No Disease", "Disease"])
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
sns.countplot(x='cp', hue='target', data=df)
plt.title('Heart Disease vs Chest Pain Type')
plt.show()

# %% [markdown]
# ##Q1: Understand the structure of the dataset?##
#
# Answer: The dataset consists of 14 features (columns) and 303 observations (rows). Most features are numerical (integers or floats), representing medical measurements like age, cholesterol, and blood pressure. The "target" column is the label we want to predict (0 = No Disease, 1 = Disease).

# %% [markdown]
# ##Q2: Identify data issues (Missing values, Outliers, Duplicates, Imbalance)?##
#
# Answer: * Missing Values: There are no missing values in this dataset.
# Duplicates: A few duplicate rows were identified and should be removed.
# Outliers: Significant outliers were found in features like 'chol' (Cholesterol) and 'trestbps' (Resting Blood Pressure).
# Imbalance: The classes are well-balanced (approx. 54% positive and 46% negative), so no special sampling is needed.

# %% [markdown]
# ##Q3: Explain insights gained from the visualizations?##
#
# Answer: 1.  Correlation: There is a strong positive correlation between 'cp' (Chest Pain type) and the target, meaning chest pain is a major indicator of heart disease.
# 2.  Age Factor: Heart disease is more prevalent in older age groups, but surprisingly, many positive cases have a high maximum heart rate ('thalach').

# %% [markdown]
# ##Q4: Propose suitable data preprocessing steps?##
# Answer:
# 1.  Data Cleaning: Remove duplicates and handle outliers using the IQR method.
# 2.  Feature Scaling: Apply StandardScaler to normalize features like age and cholesterol.
# 3.  Encoding: Use One-Hot Encoding for categorical variables such as 'cp' and 'thal' to ensure the model interprets them correctly.

# %%
numeric_cols = ['trestbps', 'chol', 'thalach', 'oldpeak']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['age', 'trestbps', 'chol', 'thalach']])
plt.title('Outliers Detection for Numerical Features')
plt.show()
